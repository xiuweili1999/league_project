# %%
# import modules
import pandas as pd
import numpy as np
import requests
import urllib.request, urllib.parse, urllib.error
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
from datetime import datetime
from ratelimit import limits
from time import time, sleep
from random import randint
import matplotlib.pyplot as plt
# %matplotlib inline
from warnings import warn

# %%
df1 = pd.read_csv('league_raw_data.csv')
df2 = pd.read_csv('league_raw_data_pt2.csv')

# %%
combined_data = pd.concat([df1, df2])

# %%
combined_data.to_csv('league_data.csv', index=False)

# %%
league_data = pd.read_csv('league_data.csv')

# %%
s = pd.Series(league_data.index // 5)
df = league_data[s.groupby(s).transform('count') == 5]

# %%
league_team_data = league_data.groupby(df.index // 5).agg({'gameId':'last','gameDuration':'last','gameVersion':'last',
                                        'teamId': 'last','win':'last','firstBlood':'last',
                                        'firstTower':'last','firstInhibitor':'last',
                                        'firstBaron':'last','firstDragon':'last',
                                        'firstRiftHerald':'last','towerKills':'last', 
                                        'inhibitorKills':'last', 'baronKills':'last', 
                                        'dragonKills':'last','riftHeraldKills':'last',
                                        'kills':'sum', 'deaths':'sum', 'assists':'sum',
                                        'totalDamageDealtToChampions':'sum', 'visionScore':'sum',
                                        'goldEarned':'sum', 'champLevel':'mean',
                                        'totalMinionsKilled':'sum'})

# %%
league_team_data.rename(columns = {'champLevel':'averageChampLevel'}, inplace = True)
league_team_data['gameDuration'] = league_team_data.gameDuration.astype(int)
league_team_data.rename(columns = {'gameDuration':'gameDuration(seconds)'}, inplace = True)

# %%
league_team_data.to_csv('league_team_data.csv', index=False)

# %%
league_team_data
# Out:
#            gameId gameDuration(seconds)    gameVersion  teamId   win  \
# 0      3380752332                  1425  10.8.317.3760     100   Win
# 1      3380752332                  1425  10.8.317.3760     200  Fail
# 2      3380718178                   915  10.8.317.3760     100  Fail
# 3      3380718178                   915  10.8.317.3760     200   Win
# 4      3380672585                  1189  10.8.317.3760     100   Win
# ...           ...                   ...            ...     ...   ...
# 31273  3333123950                  1329  10.6.313.8894     200  Fail
# 31274  3333058113                  2104  10.6.313.8894     100   Win
# 31275  3333058113                  2104  10.6.313.8894     200  Fail
# 31276  3332433241                  1370  10.6.313.8894     100   Win
# 31277  3332433241                  1370  10.6.313.8894     200  Fail
#
#        firstBlood  firstTower  firstInhibitor  firstBaron  firstDragon  ...  \
# 0            True        True            True        True         True  ...
# 1           False       False           False       False        False  ...
# 2           False       False           False       False        False  ...
# 3            True       False           False       False         True  ...
# 4            True        True           False       False        False  ...
# ...           ...         ...             ...         ...          ...  ...
# 31273       False       False           False       False         True  ...
# 31274       False        True           False       False        False  ...
# 31275        True       False            True        True         True  ...
# 31276        True        True            True        True        False  ...
# 31277       False       False           False       False         True  ...
#
#        dragonKills  riftHeraldKills  kills  deaths  assists  \
# 0                4                2     26       7       49
# 1                0                0      7      26       15
# 2                0                1      6      17       14
# 3                2                0     17       6       20
# 4                1                1     26      12       35
# ...            ...              ...    ...     ...      ...
# 31273            1                0     17      36       26
# 31274            3                1     33      33       62
# 31275            2                1     33      33       65
# 31276            1                2     34      14       63
# 31277            1                0     14      34       22
#
#        totalDamageDealtToChampions  visionScore  goldEarned  \
# 0                            60502           97       51396
# 1                            33115          106       34647
# 2                            25786           64       25552
# 3                            30792           67       28068
# 4                            47356          107       41914
# ...                            ...          ...         ...
# 31273                        45682          119       40366
# 31274                       121369          167       68732
# 31275                       124156          189       68457
# 31276                        82909          133       52991
# 31277                        47680          105       34816
#
#        averageChampLevel  totalMinionsKilled
# 0                   13.4                 586
# 1                   11.2                 474
# 2                    9.0                 361
# 3                    9.4                 324
# 4                   11.8                 503
# ...                  ...                 ...
# 31273               11.2                 489
# 31274               16.8                 781
# 31275               16.2                 747
# 31276               13.4                 548
# 31277               11.4                 471
#
# [31278 rows x 24 columns]
